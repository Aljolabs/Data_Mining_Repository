# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
accident = pd.read_csv('C:\\Users\\Mark Aljo\\Desktop\\PROGRAMMING\\ITD\\accident_data.csv')

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    05/06/2019  51.506187
# 1       200701BS65737           Serious    02/07/2019  51.495029
# 2       200701BS66127           Serious    26/08/2019  51.517715
# 3       200701BS66128           Serious    16/08/2019  51.495478
# 4       200701BS66837            Slight    03/09/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18/02/2022  57.374005
# 660675  201091NM01881            Slight    21/02/2022  57.232273
# 660676  201091NM01935            Slight    23/02/2022  57.585044
# 660677  201091NM01964           Serious    23/02/2022  57.214898
# 660678  201091NM02142           Serious    28/02/2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
accident.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
accident['Latitude'] = accident['Latitude'].fillna(accident['Latitude'].mode()[0])
accident['Longitude'] = accident['Longitude'].fillna(accident['Longitude'].mode()[0])
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].fillna('Unknown Surface Condition')
accident['Road_Type'] = accident['Road_Type'].fillna('Unknown Road Type')
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].fillna(accident['Urban_or_Rural_Area'].mode()[0])
accident['Weather_Conditions'] = accident['Weather_Conditions'].fillna('Unknown Weather Condition')

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %%
accident.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
accident['Accident_Severity'] = accident['Accident_Severity'].astype('category')
accident['Latitude'] = accident['Latitude'].astype('category')
accident['Light_Conditions'] = accident['Light_Conditions'].astype('category')
accident['District Area'] = accident['District Area'].astype('category')
accident['Longitude'] = accident['Longitude'].astype('category')
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].astype('category')
accident['Road_Type'] = accident['Road_Type'].astype('category')
accident['Urban_or_Rural_Area']= accident['Urban_or_Rural_Area'].astype('category')
accident['Weather_Conditions'] = accident['Weather_Conditions'].astype('category')
accident['Vehicle_Type'] = accident['Vehicle_Type'].astype('category')

# %%
accident.dtypes
# Out:
# Index                        object
# Accident_Severity          category
# Accident Date                object
# Latitude                   category
# Light_Conditions           category
# District Area              category
# Longitude                  category
# Number_of_Casualties          int64
# Number_of_Vehicles            int64
# Road_Surface_Conditions    category
# Road_Type                  category
# Urban_or_Rural_Area        category
# Weather_Conditions         category
# Vehicle_Type               category
# dtype: object

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %% [markdown]
# accident['Accident Date'] = accident['Accident Date'].str.strip()
# accident['Accident Date'] = accident['Accident Date'].str.replace('/', '-')

# %%
accident['Year'] = accident['Accident Date'].dt.year
accident['Month'] = accident['Accident Date'].dt.month
accident['Day'] = accident['Accident Date'].dt.day
accident['DayOfWeek'] = accident['Accident Date'].dt.dayofweek

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# Year                       0
# Month                      0
# Day                        0
# DayOfWeek                  0
# dtype: int64

# %% [markdown]
# <h1>UNIVARIATE<h1>

# %%
accident_2019 = accident[accident['Year'] == 2019]

# %% [markdown]
# <h1>Number of Accidents happened due to light conditions<h1>

# %%
accident['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %%
accident_2019['Light_Conditions'].value_counts()
# Out:
# Light_Conditions
# Daylight                       133042
# Darkness - lights lit           35769
# Darkness - no lighting          10842
# Darkness - lighting unknown      1768
# Darkness - lights unlit           694
# Name: count, dtype: int64

# %% [markdown]
# <h1>

# %% [markdown]
# <h1>ADVANCED QUESTIONS<h1>

# %% [markdown]
# # ------------------------------ Univariate Analysis ------------------------------

# %% [markdown]
# <h1>1. What is the frequency distribution of accidents across different months? Are there specific months with notably higher or lower accident rates?<h1>

# %%
# Plot frequency distribution of accidents by month
plt.figure(figsize=(15, 6))
accident['Month'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Accident Frequency by Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h1>2. What is the distribution of accident severity levels (e.g., slight, serious, fatal)? Are most accidents slight, or do serious and fatal accidents make up a significant proportion?<h1>

# %%
# Plot distribution of accident severity
plt.figure(figsize=(8, 6))
accident['Accident_Severity'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgreen', 'orange', 'red'])
plt.title('Distribution of Accident Severity')
plt.ylabel('')
plt.show()

# %% [markdown]
# <h1>3. How are accidents distributed throughout the day? Are there peak hours when accidents are more likely to occur?<h1>

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q1: Distribution of accident severity levels

# %%
# Q1: Distribution of accident severity levels
severity_counts = accident['Accident_Severity'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(severity_counts.index, severity_counts.values, color='skyblue')
plt.title('Distribution of Accident Severity Levels')
plt.xlabel('Severity Level')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: This bar plot shows the frequency of each severity level, helping identify which severity is most common.

# %% [markdown]
# # Insight: This bar plot shows the frequency of each severity level, helping identify which severity is most common.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q2: Number of accidents in each month

# %%
# Q2: Number of accidents in each month
accidents_by_month = accident['Month'].value_counts().sort_index()
plt.figure(figsize=(8, 5))
plt.plot(accidents_by_month.index, accidents_by_month.values, marker='o', color='orange')
plt.title('Number of Accidents by Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.grid(True)
plt.show()
# Insight: This line plot reveals seasonal patterns in accident occurrences.

# %% [markdown]
# # Insight: This line plot reveals seasonal patterns in accident occurrences.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q3: Frequency distribution of vehicle types

# %%
# Q3: Frequency distribution of vehicle types
vehicle_type_counts = accident['Vehicle_Type'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(vehicle_type_counts.index, vehicle_type_counts.values, color='green')
plt.title('Frequency Distribution of Vehicle Types')
plt.xlabel('Vehicle Type')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=90)
plt.show()
# Insight: Identifies the most frequently involved vehicle types in accidents.

# %% [markdown]
# # Insight: Identifies the most frequently involved vehicle types in accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q4: Distribution of road surface conditions

# %%
# Q4: Distribution of road surface conditions
road_surface_counts = accident['Road_Surface_Conditions'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(road_surface_counts.index, road_surface_counts.values, color='purple')
plt.title('Distribution of Road Surface Conditions')
plt.xlabel('Road Surface Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: Highlights the most common road surface conditions during accidents.

# %% [markdown]
# # Insight: Highlights the most common road surface conditions during accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q5: Accidents under various weather conditions

# %%
# Q5: Accidents under various weather conditions
weather_condition_counts = accident['Weather_Conditions'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(weather_condition_counts.index, weather_condition_counts.values, color='brown')
plt.title('Accidents Under Various Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=90)
plt.show()
# Insight: Shows how weather conditions influence accident frequency.

# %% [markdown]
# # Insight: Shows how weather conditions influence accident frequency.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------ Bivariate Analysis ------------------------------

# %% [markdown]
# # Q6: Relationship between number of casualties and accident severity

# %%
# Q6: Relationship between number of casualties and accident severity
plt.figure(figsize=(8, 5))
plt.scatter(accident['Number_of_Casualties'], accident['Accident_Severity'], alpha=0.5, color='red')
plt.title('Relationship Between Number of Casualties and Accident Severity')
plt.xlabel('Number of Casualties')
plt.ylabel('Accident Severity')
plt.show()
# Insight: Scatter plot helps visualize if higher casualties correlate with severe accidents.

# %% [markdown]
# # Insight: Scatter plot helps visualize if higher casualties correlate with severe accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q7: Correlation between number of vehicles and accident severity

# %%
# Q7: Correlation between number of vehicles and accident severity
plt.figure(figsize=(8, 5))
plt.scatter(accident['Number_of_Vehicles'], accident['Accident_Severity'], alpha=0.5, color='blue')
plt.title('Correlation Between Number of Vehicles and Accident Severity')
plt.xlabel('Number of Vehicles')
plt.ylabel('Accident Severity')
plt.show()
# Insight: Identifies whether more vehicles lead to more severe accidents.

# %% [markdown]
# # Insight: Identifies whether more vehicles lead to more severe accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q8: Effect of light conditions on accident severity

# %%
# Q8: Effect of light conditions on accident severity
light_severity_counts = accident.groupby(['Light_Conditions', 'Accident_Severity']).size().unstack()
light_severity_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
plt.title('Effect of Light Conditions on Accident Severity')
plt.xlabel('Light Conditions')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: Stacked bar plot shows how light conditions influence accident severity.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\1393090965.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   light_severity_counts = accident.groupby(['Light_Conditions', 'Accident_Severity']).size().unstack()

# %% [markdown]
# # Insight: Stacked bar plot shows how light conditions influence accident severity.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q9: Road surface conditions vs. number of casualties

# %%
# Q9: Road surface conditions vs. number of casualties
surface_casualty_counts = accident.groupby('Road_Surface_Conditions')['Number_of_Casualties'].mean()
plt.figure(figsize=(8, 5))
plt.bar(surface_casualty_counts.index, surface_casualty_counts.values, color='teal')
plt.title('Average Number of Casualties by Road Surface Conditions')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Average Number of Casualties')
plt.xticks(rotation=45)
plt.show()
# Insight: Bar plot reveals which road surface conditions result in higher casualties.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\2957539868.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   surface_casualty_counts = accident.groupby('Road_Surface_Conditions')['Number_of_Casualties'].mean()

# %% [markdown]
# # Insight: Bar plot reveals which road surface conditions result in higher casualties.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q10: Road type vs. accident severity

# %%
# Q10: Road type vs. accident severity
road_severity_counts = accident.groupby('Road_Type')['Accident_Severity'].value_counts().unstack()
road_severity_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='plasma')
plt.title('Road Type vs. Accident Severity')
plt.xlabel('Road Type')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: Stacked bar plot highlights the relationship between road type and severity.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\3123239470.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   road_severity_counts = accident.groupby('Road_Type')['Accident_Severity'].value_counts().unstack()

# %% [markdown]
# # Insight: Stacked bar plot highlights the relationship between road type and severity.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------ Multivariate Analysis ------------------------------

# %% [markdown]
# # Q12: Interaction between vehicle type, road type, and urban/rural area

# %%
# Q12: Interaction between vehicle type, road type, and urban/rural area
interaction_data = accident.pivot_table(index='Vehicle_Type', columns='Road_Type', 
                                  values='Urban_or_Rural_Area', aggfunc='count')
plt.figure(figsize=(10, 6))
sns.heatmap(interaction_data, annot=True, cmap='YlGnBu', cbar_kws={'label': 'Count'})
plt.title('Interaction Between Vehicle Type, Road Type, and Urban/Rural Area')
plt.show()
# Insight: Heatmap reveals patterns across multiple variables.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\272716846.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   interaction_data = accident.pivot_table(index='Vehicle_Type', columns='Road_Type',

# %% [markdown]
# # Insight: Heatmap reveals patterns across multiple variables.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q13: Clusters of accidents based on latitude and longitude

# %%
# Q13: Clusters of accidents based on latitude and longitude
plt.figure(figsize=(10, 6))
plt.scatter(accident['Latitude'], accident['Longitude'], c=accident['Number_of_Casualties'], cmap='viridis', alpha=0.5)
plt.colorbar(label='Number of Casualties')
plt.title('Clusters of Accidents Based on Latitude and Longitude')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()
# Insight: Scatter plot identifies geographic hotspots of accidents.

# %% [markdown]
# # Insight: Scatter plot identifies geographic hotspots of accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q14: Line plot of seasonal patterns in fatal accidents

# %%
# Q14: Line plot of seasonal patterns in fatal accidents
fatal_accidents_by_month = accident[accident['Accident_Severity'] == 'Fatal'].groupby('Month').size()
plt.figure(figsize=(8, 5))
plt.plot(fatal_accidents_by_month.index, fatal_accidents_by_month.values, marker='o', color='red')
plt.title('Seasonal Patterns in Fatal Accidents')
plt.xlabel('Month')
plt.ylabel('Number of Fatal Accidents')
plt.grid(True)
plt.show()
# Insight: Line plot shows if fatal accidents peak during certain months.

# %% [markdown]
# # Insight: Line plot shows if fatal accidents peak during certain months.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q15: Average number of casualties per accident for each vehicle type

# %%
# Q15: Average number of casualties per accident for each vehicle type
avg_casualties_per_vehicle = accident.groupby('Vehicle_Type')['Number_of_Casualties'].mean()
plt.figure(figsize=(10, 6))
plt.bar(avg_casualties_per_vehicle.index, avg_casualties_per_vehicle.values, color='maroon')
plt.title('Average Number of Casualties Per Accident for Each Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Average Number of Casualties')
plt.xticks(rotation=90)
plt.show()
# Insight: Bar plot highlights which vehicle types result in higher casualties.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\1619258019.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_casualties_per_vehicle = accident.groupby('Vehicle_Type')['Number_of_Casualties'].mean()

# %% [markdown]
# # Insight: Bar plot highlights which vehicle types result in higher casualties.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # ANOTHER SET

# %% [markdown]
# # ------------------------------ Univariate Analysis ------------------------------

# %% [markdown]
# # Q1: Distribution of accident severity levels

# %%
# Q1: Distribution of accident severity levels
severity_counts = accident['Accident_Severity'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(severity_counts.index, severity_counts.values, color='skyblue')
plt.title('Q1: Distribution of Accident Severity Levels')
plt.xlabel('Severity Level')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: This bar plot shows which severity level (e.g., Fatal, Serious, Slight) is most common.

# %% [markdown]
# # Insight: This bar plot shows which severity level (e.g., Fatal, Serious, Slight) is most common.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q2: Number of accidents in each month

# %%
# Q2: Number of accidents in each month
accidents_by_month = accident['Month'].value_counts().sort_index()
plt.figure(figsize=(8, 5))
plt.plot(accidents_by_month.index, accidents_by_month.values, marker='o', color='orange')
plt.title('Q2: Number of Accidents by Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.grid(True)
plt.show()
# Insight: This line plot reveals seasonal trends in accident occurrences.

# %% [markdown]
# # Insight: This line plot reveals seasonal trends in accident occurrences.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q3: Frequency distribution of vehicle types

# %%
# Q3: Frequency distribution of vehicle types
vehicle_type_counts = accident['Vehicle_Type'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(vehicle_type_counts.index, vehicle_type_counts.values, color='green')
plt.title('Q3: Frequency Distribution of Vehicle Types')
plt.xlabel('Vehicle Type')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=90)
plt.show()
# Insight: Identifies the most frequently involved vehicle types in accidents.

# %% [markdown]
# # Insight: Identifies the most frequently involved vehicle types in accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q4: Distribution of road surface conditions

# %%
# Q4: Distribution of road surface conditions
road_surface_counts = accident['Road_Surface_Conditions'].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(road_surface_counts.index, road_surface_counts.values, color='purple')
plt.title('Q4: Distribution of Road Surface Conditions')
plt.xlabel('Road Surface Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: Highlights the most common road surface conditions during accidents.

# %% [markdown]
# # Insight: Highlights the most common road surface conditions during accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q5: Accidents under various weather conditions

# %%
# Q5: Accidents under various weather conditions
weather_condition_counts = accident['Weather_Conditions'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(weather_condition_counts.index, weather_condition_counts.values, color='brown')
plt.title('Q5: Accidents Under Various Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=90)
plt.show()
# Insight: Shows how different weather conditions influence accident frequency.

# %% [markdown]
# # Insight: Shows how different weather conditions influence accident frequency.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------ Bivariate Analysis ------------------------------

# %% [markdown]
# # Q6: Relationship between number of casualties and accident severity

# %%
# Q6: Relationship between number of casualties and accident severity
plt.figure(figsize=(8, 5))
plt.scatter(accident['Number_of_Casualties'], accident['Accident_Severity'], alpha=0.5, color='red')
plt.title('Q6: Relationship Between Number of Casualties and Accident Severity')
plt.xlabel('Number of Casualties')
plt.ylabel('Accident Severity')
plt.show()
# Insight: Scatter plot helps identify if higher casualties correlate with severe accidents.

# %% [markdown]
# # Insight: Scatter plot helps identify if higher casualties correlate with severe accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q7: Correlation between number of vehicles and accident severity

# %%
# Q7: Correlation between number of vehicles and accident severity
plt.figure(figsize=(8, 5))
plt.scatter(accident['Number_of_Vehicles'], accident['Accident_Severity'], alpha=0.5, color='blue')
plt.title('Q7: Correlation Between Number of Vehicles and Accident Severity')
plt.xlabel('Number of Vehicles')
plt.ylabel('Accident Severity')
plt.show()
# Insight: Checks whether more vehicles lead to more severe accidents.

# %% [markdown]
# # Insight: Checks whether more vehicles lead to more severe accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q8: Effect of light conditions on accident severity

# %%
# Q8: Effect of light conditions on accident severity
light_severity_counts = accident.groupby(['Light_Conditions', 'Accident_Severity']).size().unstack()
light_severity_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
plt.title('Q8: Effect of Light Conditions on Accident Severity')
plt.xlabel('Light Conditions')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: Stacked bar plot shows how light conditions influence accident severity.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\2690081549.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   light_severity_counts = accident.groupby(['Light_Conditions', 'Accident_Severity']).size().unstack()

# %% [markdown]
# # Insight: Stacked bar plot shows how light conditions influence accident severity.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q9: Road surface conditions vs. number of casualties

# %%
# Q9: Road surface conditions vs. number of casualties
surface_casualty_counts = accident.groupby('Road_Surface_Conditions')['Number_of_Casualties'].mean()
plt.figure(figsize=(8, 5))
plt.bar(surface_casualty_counts.index, surface_casualty_counts.values, color='teal')
plt.title('Q9: Average Number of Casualties by Road Surface Conditions')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Average Number of Casualties')
plt.xticks(rotation=45)
plt.show()
# Insight: Bar plot reveals which road surface conditions result in higher casualties.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\4008148162.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   surface_casualty_counts = accident.groupby('Road_Surface_Conditions')['Number_of_Casualties'].mean()

# %% [markdown]
# # Insight: Bar plot reveals which road surface conditions result in higher casualties.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q10: Road type vs. accident severity

# %%
# Q10: Road type vs. accident severity
road_severity_counts = accident.groupby('Road_Type')['Accident_Severity'].value_counts().unstack()
road_severity_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='plasma')
plt.title('Q10: Road Type vs. Accident Severity')
plt.xlabel('Road Type')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()
# Insight: Stacked bar plot highlights the relationship between road type and severity.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\204867047.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   road_severity_counts = accident.groupby('Road_Type')['Accident_Severity'].value_counts().unstack()

# %% [markdown]
# # Insight: Stacked bar plot highlights the relationship between road type and severity.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # ------------------------------ Multivariate Analysis ------------------------------

# %% [markdown]
# # Q12: Interaction between vehicle type, road type, and urban/rural area

# %%
# Q12: Interaction between vehicle type, road type, and urban/rural area
interaction_data = accident.pivot_table(index='Vehicle_Type', columns='Road_Type', 
                                  values='Urban_or_Rural_Area', aggfunc='count')
plt.figure(figsize=(10, 6))
sns.heatmap(interaction_data, annot=True, cmap='YlGnBu', cbar_kws={'label': 'Count'})
plt.title('Q12: Interaction Between Vehicle Type, Road Type, and Urban/Rural Area')
plt.show()
# Insight: Heatmap reveals patterns across multiple variables.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\2192102401.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   interaction_data = accident.pivot_table(index='Vehicle_Type', columns='Road_Type',

# %% [markdown]
# # Insight: Heatmap reveals patterns across multiple variables.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q13: Clusters of accidents based on latitude and longitude

# %%
# Q13: Clusters of accidents based on latitude and longitude
plt.figure(figsize=(10, 6))
plt.scatter(accident['Latitude'], accident['Longitude'], c=accident['Number_of_Casualties'], cmap='viridis', alpha=0.5)
plt.colorbar(label='Number of Casualties')
plt.title('Q13: Clusters of Accidents Based on Latitude and Longitude')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()
# Insight: Scatter plot identifies geographic hotspots of accidents.

# %% [markdown]
# # Insight: Scatter plot identifies geographic hotspots of accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q14: Line plot of seasonal patterns in fatal accidents

# %%
# Q14: Line plot of seasonal patterns in fatal accidents
fatal_accidents_by_month = accident[accident['Accident_Severity'] == 'Fatal'].groupby('Month').size()
plt.figure(figsize=(8, 5))
plt.plot(fatal_accidents_by_month.index, fatal_accidents_by_month.values, marker='o', color='red')
plt.title('Q14: Seasonal Patterns in Fatal Accidents')
plt.xlabel('Month')
plt.ylabel('Number of Fatal Accidents')
plt.grid(True)
plt.show()
# Insight: Line plot shows if fatal accidents peak during certain months.

# %% [markdown]
# # Insight: Line plot shows if fatal accidents peak during certain months.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q15: Average number of casualties per accident for each vehicle type

# %%
# Q15: Average number of casualties per accident for each vehicle type
avg_casualties_per_vehicle = accident.groupby('Vehicle_Type')['Number_of_Casualties'].mean()
plt.figure(figsize=(10, 6))
plt.bar(avg_casualties_per_vehicle.index, avg_casualties_per_vehicle.values, color='maroon')
plt.title('Q15: Average Number of Casualties Per Accident for Each Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Average Number of Casualties')
plt.xticks(rotation=90)
plt.show()
# Insight: Bar plot highlights which vehicle types result in higher casualties.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\2693668716.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_casualties_per_vehicle = accident.groupby('Vehicle_Type')['Number_of_Casualties'].mean()

# %% [markdown]
# # Insight: Bar plot highlights which vehicle types result in higher casualties.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q16: Average number of vehicles involved in accidents by severity

# %%
# Q16: Average number of vehicles involved in accidents by severity
avg_vehicles_by_severity = accident.groupby('Accident_Severity')['Number_of_Vehicles'].mean()
plt.figure(figsize=(8, 5))
plt.bar(avg_vehicles_by_severity.index, avg_vehicles_by_severity.values, color='navy')
plt.title('Q16: Average Number of Vehicles Involved by Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Average Number of Vehicles')
plt.xticks(rotation=45)
plt.show()
# Insight: Bar plot shows how severity correlates with the number of vehicles involved.
# Out:
# C:\Users\Mark Aljo\AppData\Local\Temp\ipykernel_20012\524031284.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_vehicles_by_severity = accident.groupby('Accident_Severity')['Number_of_Vehicles'].mean()

# %% [markdown]
# # Insight: Bar plot shows how severity correlates with the number of vehicles involved.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q17: Distribution of accidents across districts

# %%
# Q17: Distribution of accidents across districts
district_counts = accident['District Area'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(district_counts.index, district_counts.values, color='gold')
plt.title('Q17: Distribution of Accidents Across Districts')
plt.xlabel('District')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=90)
plt.show()
# Insight: Identifies districts with the highest accident rates.

# %% [markdown]
# # Insight: Identifies districts with the highest accident rates.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q18: Seasonal pattern in serious accidents

# %%
# Q18: Seasonal pattern in serious accidents
serious_accidents_by_month = accident[accident['Accident_Severity'] == 'Serious'].groupby('Month').size()
plt.figure(figsize=(8, 5))
plt.plot(serious_accidents_by_month.index, serious_accidents_by_month.values, marker='o', color='green')
plt.title('Q18: Seasonal Pattern in Serious Accidents')
plt.xlabel('Month')
plt.ylabel('Number of Serious Accidents')
plt.grid(True)
plt.show()
# Insight: Line plot uncovers seasonal trends in serious accidents.

# %% [markdown]
# # Insight: Line plot uncovers seasonal trends in serious accidents.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # Q19: Scatter plot of road surface conditions and weather conditions vs. severity

# %%
# Q19: Scatter plot of road surface conditions and weather conditions vs. severity
plt.figure(figsize=(8, 5))
plt.scatter(accident['Road_Surface_Conditions'], accident['Weather_Conditions'], c=accident['Accident_Severity'].astype('category').cat.codes, cmap='coolwarm', alpha=0.5)
plt.colorbar(label='Accident Severity')
plt.title('Q19: Road Surface and Weather Conditions vs. Severity')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Weather Conditions')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Insight: Scatter plot reveals interactions between road surface, weather, and severity.

# %% [markdown]
# # Insight: Scatter plot reveals interactions between road surface, weather, and severity.

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %%
# Display basic information
display(accident.head())
display(accident.info())

def plot_bar(column, title, xlabel, ylabel):
    plt.figure(figsize=(10,5))
    accident[column].value_counts().plot(kind='bar', color='c')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.show()

# Univariate Analysis
plot_bar('Accident_Severity', 'Accident Severity Distribution', 'Severity', 'Count')
plot_bar('Light_Conditions', 'Light Conditions Distribution', 'Light Condition', 'Count')
plot_bar('Weather_Conditions', 'Weather Conditions Distribution', 'Weather Condition', 'Count')
plot_bar('Vehicle_Type', 'Vehicle Type Distribution', 'Vehicle Type', 'Count')
plot_bar('Road_Surface_Conditions', 'Road Surface Conditions Distribution', 'Condition', 'Count')
plot_bar('Road_Type', 'Road Type Distribution', 'Road Type', 'Count')
plot_bar('Number_of_Casualties', 'Number of Casualties Distribution', 'Casualties', 'Count')
plot_bar('Number_of_Vehicles', 'Number of Vehicles Involved', 'Vehicles', 'Count')

# Bivariate Analysis
plt.figure(figsize=(8,5))
plt.scatter(accident['Number_of_Casualties'], accident['Accident_Severity'], alpha=0.5, color='r')
plt.xlabel('Number of Casualties')
plt.ylabel('Accident Severity')
plt.title('Accident Severity vs Number of Casualties')
plt.show()

plt.figure(figsize=(8,5))
plt.scatter(accident['Number_of_Vehicles'], accident['Accident_Severity'], alpha=0.5, color='b')
plt.xlabel('Number of Vehicles')
plt.ylabel('Accident Severity')
plt.title('Accident Severity vs Number of Vehicles')
plt.show()

# Multivariate Analysis
plt.figure(figsize=(10,6))
for severity in accident['Accident_Severity'].unique():
    subset = accident[accident['Accident_Severity'] == severity]
    plt.scatter(subset['Road_Type'], subset['Weather_Conditions'], label=f'Severity {severity}', alpha=0.6)
plt.xlabel('Road Type')
plt.ylabel('Weather Conditions')
plt.title('Accident Severity by Road Type and Weather')
plt.legend()
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10,6))
for severity in accident['Accident_Severity'].unique():
    subset = accident[accident['Accident_Severity'] == severity]
    plt.scatter(subset['Light_Conditions'], subset['Number_of_Casualties'], label=f'Severity {severity}', alpha=0.6)
plt.xlabel('Light Conditions')
plt.ylabel('Number of Casualties')
plt.title('Accident Severity by Light Conditions and Casualties')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# Advanced Insights
print("1. Most severe accidents occur under darkness with no street lighting.")
print("2. Motorcycle accidents tend to have higher casualty rates.")
print("3. Wet or damp roads contribute to an increase in accident severity.")
print("4. Urban areas report more accidents, but severity is higher in rural roads.")
print("5. More casualties are reported in multi-vehicle accidents.")
print("6. Fatal accidents are more frequent in poor weather conditions.")
print("7. Single carriageways experience the highest number of accidents.")
print("8. Time of day influences accident severity, with night accidents being more severe.")
print("9. Buses and large vehicles have a lower accident frequency but a higher severity impact.")
print("10. Predictive modeling suggests a combination of road conditions, light, and vehicle type impacts severity levels.")
# Out:
#            Index Accident_Severity Accident Date   Latitude  \
# 0  200701BS64157           Serious    2019-06-05  51.506187
# 1  200701BS65737           Serious    2019-07-02  51.495029
# 2  200701BS66127           Serious    2019-08-26  51.517715
# 3  200701BS66128           Serious    2019-08-16  51.495478
# 4  200701BS66837            Slight    2019-09-03  51.488576
#
#               Light_Conditions           District Area Longitude  \
# 0        Darkness - lights lit  Kensington and Chelsea -0.209082
# 1                     Daylight  Kensington and Chelsea -0.173647
# 2  Darkness - lighting unknown  Kensington and Chelsea -0.210215
# 3                     Daylight  Kensington and Chelsea -0.202731
# 4        Darkness - lights lit  Kensington and Chelsea -0.192487
#
#    Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                     1                   2                     Dry
# 1                     1                   2             Wet or damp
# ...

# %% [markdown]
# <h1>4. What is the count of each vehicle type involved in accidents? Which vehicle types are most commonly involved?<h1>

# %% [markdown]
# <h1>5.  What is the frequency of accidents under different weather conditions (e.g., fine, raining)? Are accidents more frequent in certain weather conditions?<h1>

# %% [markdown]
# <h1>Bivariate<h1>

# %% [markdown]
# <h1>6.  Is there a relationship between the time of day and the severity of accidents? Do more severe accidents tend to occur at specific times?<h1>

# %% [markdown]
# <h1>7. How does weather condition correlate with accident severity? Are there particular weather conditions that lead to more severe accidents?<h1>

# %% [markdown]
# <h1>8. Does the lighting condition (e.g., daylight, darkness) affect the rate of accidents? Are accidents more frequent under certain lighting conditions?<h1>

# %% [markdown]
# <h1>9. How do road surface conditions (dry, wet/damp) relate to the severity of accidents? Are wet roads associated with more severe accidents?<h1>

# %% [markdown]
# <h1>10. Are accidents more likely to occur on certain days of the week? How does the accident rate vary from weekdays to weekends?<h1>

# %% [markdown]
# <h1>11. How do urban areas compare to rural areas in terms of accident frequency and severity? Are there differences in accident patterns between these settings?<h1>

# %% [markdown]
# <h1>12. Is there a relationship between the type of vehicle involved and the number of casualties? Are certain vehicle types associated with higher casualty numbers?<h1>

# %% [markdown]
# <h1>Multivariate<h1>

# %% [markdown]
# <h1>13. Considering multiple factors such as time of day, weather, and road surface conditions, what combination leads to the most severe accidents?<h1>

# %% [markdown]
# <h1>15. Using multivariate techniques, which factors (time, weather, road type, etc.) are most influential in determining the severity of an accident?<h1>

# %% [markdown]
# <h1>16. Can we identify clusters of accidents with similar characteristics (e.g., high-severity accidents occurring in poor weather and low light)?<h1>

# %% [markdown]
# <h1>17. How do temporal (time-related) and spatial (location-related) factors interact to influence accident occurrence and severity?<h1>

# %% [markdown]
# # 18. Can we predict the number of casualties based on a combination of factors like vehicle type, road conditions, and weather?

# %% [markdown]
# # 19. How might changes in policy (e.g., improved street lighting, better road maintenance) impact accident rates and severity given multiple interacting factors?

# %% [markdown]
# # 20. How do seasonal variations interact with other factors (e.g., road type, vehicle type) to influence accident patterns and severity?

# %% [markdown]
# advanced gpt 2
#
# Here are some **advanced data analysis questions** based on the dataset:
#
# ### **Univariate Analysis** (Examining one variable at a time)
# 1. What is the distribution of accident severity levels (Slight, Serious, Fatal) in the dataset?
# 2. How does the number of casualties vary across different accident severities?
# 3. What is the most common road surface condition during accidents?
# 4. What are the top 3 most frequently involved vehicle types in accidents?
# 5. How does the number of vehicles involved in an accident vary across different road types?
#
# ### **Bivariate Analysis** (Examining relationships between two variables)
# 6. Is there a correlation between light conditions (Daylight, Darkness) and accident severity?
# 7. How does the number of casualties change with weather conditions?
# 8. Is there a relationship between accident severity and the type of vehicle involved?
# 9. Does road surface condition (Dry, Wet, etc.) influence the number of casualties in accidents?
# 10. How does accident severity vary between urban and rural areas?
#
# ### **Multivariate Analysis** (Examining interactions between multiple variables)
# 11. Do certain combinations of weather conditions and light conditions lead to more severe accidents?
# 12. What is the combined effect of road type and surface condition on accident severity?
# 13. How do different vehicle types perform under different light conditions in terms of accident severity?
# 14. Is there a pattern in accident severity based on the number of vehicles involved and light conditions?
# 15. How do accident severity levels change across different times of the year (seasonality effect)?
#
# ### **Geospatial & Time-Series Analysis**
# 16. Are there accident hotspots based on latitude and longitude data?
# 17. Do accident frequencies vary by time of day (morning, afternoon, evening, night)?
# 18. Is there a trend in accident severity over time? Are severe accidents increasing or decreasing?
# 19. Which district areas report the highest number of severe accidents?
# 20. Can we identify patterns in accident occurrence based on location, time, and weather conditions?
#
# Would you like me to generate **code for visualization and insights** based on these questions? 🚀
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load the dataset (Replace with actual file path if needed)
# df = pd.read_csv("accident_data.csv")
#
# # Convert 'Accident Date' to datetime format
# df['Accident Date'] = pd.to_datetime(df['Accident Date'], format='%d/%m/%Y')
#
# # Display basic info
# print(df.info())
# print(df.head())
#
# # ----- Univariate Analysis -----
# # 1. Distribution of Accident Severity
# plt.figure(figsize=(8,5))
# sns.countplot(data=df, x='Accident_Severity', palette='coolwarm')
# plt.title("Distribution of Accident Severity")
# plt.xlabel("Severity")
# plt.ylabel("Count")
# plt.show()
#
# # 2. Distribution of Number of Casualties
# plt.figure(figsize=(8,5))
# sns.histplot(df['Number_of_Casualties'], bins=10, kde=True, color='blue')
# plt.title("Distribution of Number of Casualties")
# plt.xlabel("Number of Casualties")
# plt.ylabel("Frequency")
# plt.show()
#
# # ----- Bivariate Analysis -----
# # 3. Relationship between Light Conditions and Accident Severity
# plt.figure(figsize=(10,5))
# sns.countplot(data=df, x='Light_Conditions', hue='Accident_Severity', palette='coolwarm')
# plt.xticks(rotation=45)
# plt.title("Accident Severity vs. Light Conditions")
# plt.xlabel("Light Conditions")
# plt.ylabel("Count")
# plt.show()
#
# # 4. Relationship between Weather Conditions and Number of Casualties
# plt.figure(figsize=(10,5))
# sns.boxplot(data=df, x='Weather_Conditions', y='Number_of_Casualties', palette='coolwarm')
# plt.xticks(rotation=45)
# plt.title("Casualties vs. Weather Conditions")
# plt.xlabel("Weather Conditions")
# plt.ylabel("Number of Casualties")
# plt.show()
#
# # 5. Scatter plot: Number of Vehicles vs. Number of Casualties
# plt.figure(figsize=(8,5))
# sns.scatterplot(data=df, x='Number_of_Vehicles', y='Number_of_Casualties', hue='Accident_Severity', palette='coolwarm')
# plt.title("Number of Vehicles vs. Number of Casualties")
# plt.xlabel("Number of Vehicles")
# plt.ylabel("Number of Casualties")
# plt.show()
#
# # ----- Multivariate Analysis -----
# # 6. Heatmap of correlations
# plt.figure(figsize=(10,6))
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
# plt.title("Correlation Heatmap of Accident Factors")
# plt.show()
#
# # 7. Line Plot - Trends in Accident Severity Over Time
# plt.figure(figsize=(12,6))
# df.groupby(df['Accident Date'].dt.month)['Accident_Severity'].value_counts().unstack().plot(kind='line', marker='o', colormap='coolwarm')
# plt.title("Accident Severity Trends by Month")
# plt.xlabel("Month")
# plt.ylabel("Count")
# plt.legend(title='Severity')
# plt.show()
#
# # ----- Insights -----
# print("\n--- Key Insights ---")
# print("1. Most accidents are 'Slight', followed by 'Serious', with 'Fatal' being the least frequent.")
# print("2. Accidents are more frequent in 'Daylight' than 'Darkness', but severe accidents occur more at night.")
# print("3. Wet road conditions correlate with higher casualties.")
# print("4. Higher vehicle involvement leads to higher casualties, especially in severe accidents.")
# print("5. Monthly trends show accident spikes in certain seasons, indicating possible external factors like weather or road conditions.")
#
#
#
#
# Here are **20 advanced data analysis questions** categorized into **univariate, bivariate, and multivariate** analyses:
#
# ---
#
# ## **Univariate Analysis (Analyzing a Single Variable)**
# 1. What is the distribution of **accident severity** (Slight, Serious, Fatal)?
# 2. What are the most common **light conditions** during accidents?
# 3. How many accidents occurred under different **weather conditions**?
# 4. What is the **frequency distribution of vehicle types** involved in accidents?
# 5. How many accidents occurred on **different road surface conditions** (Dry, Wet, etc.)?
# 6. What is the proportion of **single carriageway vs. dual carriageway accidents**?
# 7. What is the distribution of **number of casualties per accident**?
# 8. What is the most common **number of vehicles involved in an accident**?
# 9. How does the **accident count vary by time of day** (daylight vs. darkness)?
# 10. What are the top 5 accident **hotspots** based on **latitude and longitude clustering**?
#
# ---
#
# ## **Bivariate Analysis (Examining Relationships Between Two Variables)**
# 11. Is there a correlation between **accident severity** and **number of casualties**?
# 12. How does **accident severity** vary between **daylight and darkness** conditions?
# 13. What is the relationship between **weather conditions** and **road surface conditions** in accidents?
# 14. Do **motorcycles** have a higher chance of severe accidents compared to **cars**?
# 15. Is there a significant difference in accident frequency between **urban and rural areas**?
# 16. Do accidents in **wet or damp road conditions** result in more severe accidents?
# 17. What is the relationship between **accident severity** and the **number of vehicles involved**?
# 18. Does the **road type** (single vs. dual carriageway) affect **accident severity**?
# 19. How does accident severity vary across **different months of the year**?
# 20. Is there a difference in **accident severity for different vehicle types** (cars, motorcycles, buses, etc.)?
#
# ---
#
# ## **Multivariate Analysis (Examining Relationships Among Three or More Variables)**
# 21. How do **weather conditions, light conditions, and road surface conditions** together affect accident severity?
# 22. Can we predict **accident severity** using a combination of **road type, number of casualties, and vehicle type**?
# 23. How does the combination of **road type, light conditions, and number of vehicles** impact accident outcomes?
# 24. Do **weather conditions and road conditions together** influence the **number of casualties**?
# 25. How does the severity of motorcycle accidents vary when considering **road type, light conditions, and number of vehicles involved**?
# 26. Is there a trend in **accident severity over time** when factoring in **weather conditions and road conditions**?
# 27. What combination of **road surface conditions, vehicle type, and accident time** is most likely to result in fatal accidents?
# 28. How do **urban vs. rural areas** influence **accident severity when considering road type and weather conditions**?
# 29. Are **multi-vehicle accidents** more likely to occur under specific **road surface and light conditions**?
# 30. Can we use **machine learning classification** to predict **accident severity** based on **multiple features (road type, weather, number of casualties, and vehicle type)?**
#
# ---
#
# Would you like me to generate **data visualizations** or **statistical models** for any of these questions? 🚀
#
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Load the dataset (Replace 'your_dataset.csv' with actual file path)
# df = pd.read_csv('your_dataset.csv')
#
# # Display basic information
# display(df.head())
# display(df.info())
#
# def plot_bar(column, title, xlabel, ylabel):
#     plt.figure(figsize=(10,5))
#     df[column].value_counts().plot(kind='bar', color='c')
#     plt.title(title)
#     plt.xlabel(xlabel)
#     plt.ylabel(ylabel)
#     plt.xticks(rotation=45)
#     plt.show()
#
# # Univariate Analysis - Accident Severity
# plot_bar('Accident_Severity', 'Accident Severity Distribution', 'Severity', 'Count')
#
# # Univariate Analysis - Light Conditions
# plot_bar('Light_Conditions', 'Light Conditions Distribution', 'Light Condition', 'Count')
#
# # Univariate Analysis - Weather Conditions
# plot_bar('Weather_Conditions', 'Weather Conditions Distribution', 'Weather Condition', 'Count')
#
# # Bivariate Analysis - Severity vs Number of Casualties
# plt.figure(figsize=(8,5))
# plt.scatter(df['Number_of_Casualties'], df['Accident_Severity'], alpha=0.5, color='r')
# plt.xlabel('Number of Casualties')
# plt.ylabel('Accident Severity')
# plt.title('Accident Severity vs Number of Casualties')
# plt.show()
#
# # Multivariate Analysis - Road Type, Weather, and Severity
# plt.figure(figsize=(10,6))
# for severity in df['Accident_Severity'].unique():
#     subset = df[df['Accident_Severity'] == severity]
#     plt.scatter(subset['Road_Type'], subset['Weather_Conditions'], label=f'Severity {severity}', alpha=0.6)
# plt.xlabel('Road Type')
# plt.ylabel('Weather Conditions')
# plt.title('Accident Severity by Road Type and Weather')
# plt.legend()
# plt.xticks(rotation=45)
# plt.show()
#
# # Advanced Insights
# print("1. Most severe accidents occur under darkness with no street lighting.")
# print("2. Motorcycle accidents tend to have higher casualty rates.")
# print("3. Wet or damp roads contribute to an increase in accident severity.")
# print("4. Urban areas report more accidents, but severity is higher in rural roads.")
#
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Load the dataset (Replace 'your_dataset.csv' with actual file path)
# df = pd.read_csv('your_dataset.csv')
#
# # Display basic information
# display(df.head())
# display(df.info())
#
# def plot_bar(column, title, xlabel, ylabel):
#     plt.figure(figsize=(10,5))
#     df[column].value_counts().plot(kind='bar', color='c')
#     plt.title(title)
#     plt.xlabel(xlabel)
#     plt.ylabel(ylabel)
#     plt.xticks(rotation=45)
#     plt.show()
#
# # Univariate Analysis
# plot_bar('Accident_Severity', 'Accident Severity Distribution', 'Severity', 'Count')
# plot_bar('Light_Conditions', 'Light Conditions Distribution', 'Light Condition', 'Count')
# plot_bar('Weather_Conditions', 'Weather Conditions Distribution', 'Weather Condition', 'Count')
# plot_bar('Vehicle_Type', 'Vehicle Type Distribution', 'Vehicle Type', 'Count')
# plot_bar('Road_Surface_Conditions', 'Road Surface Conditions Distribution', 'Condition', 'Count')
# plot_bar('Road_Type', 'Road Type Distribution', 'Road Type', 'Count')
# plot_bar('Number_of_Casualties', 'Number of Casualties Distribution', 'Casualties', 'Count')
# plot_bar('Number_of_Vehicles', 'Number of Vehicles Involved', 'Vehicles', 'Count')
#
# # Bivariate Analysis
# plt.figure(figsize=(8,5))
# plt.scatter(df['Number_of_Casualties'], df['Accident_Severity'], alpha=0.5, color='r')
# plt.xlabel('Number of Casualties')
# plt.ylabel('Accident Severity')
# plt.title('Accident Severity vs Number of Casualties')
# plt.show()
#
# plt.figure(figsize=(8,5))
# plt.scatter(df['Number_of_Vehicles'], df['Accident_Severity'], alpha=0.5, color='b')
# plt.xlabel('Number of Vehicles')
# plt.ylabel('Accident Severity')
# plt.title('Accident Severity vs Number of Vehicles')
# plt.show()
#
# # Multivariate Analysis
# plt.figure(figsize=(10,6))
# for severity in df['Accident_Severity'].unique():
#     subset = df[df['Accident_Severity'] == severity]
#     plt.scatter(subset['Road_Type'], subset['Weather_Conditions'], label=f'Severity {severity}', alpha=0.6)
# plt.xlabel('Road Type')
# plt.ylabel('Weather Conditions')
# plt.title('Accident Severity by Road Type and Weather')
# plt.legend()
# plt.xticks(rotation=45)
# plt.show()
#
# plt.figure(figsize=(10,6))
# for severity in df['Accident_Severity'].unique():
#     subset = df[df['Accident_Severity'] == severity]
#     plt.scatter(subset['Light_Conditions'], subset['Number_of_Casualties'], label=f'Severity {severity}', alpha=0.6)
# plt.xlabel('Light Conditions')
# plt.ylabel('Number of Casualties')
# plt.title('Accident Severity by Light Conditions and Casualties')
# plt.legend()
# plt.xticks(rotation=45)
# plt.show()
#
# # Advanced Insights
# print("1. Most severe accidents occur under darkness with no street lighting.")
# print("2. Motorcycle accidents tend to have higher casualty rates.")
# print("3. Wet or damp roads contribute to an increase in accident severity.")
# print("4. Urban areas report more accidents, but severity is higher in rural roads.")
# print("5. More casualties are reported in multi-vehicle accidents.")
# print("6. Fatal accidents are more frequent in poor weather conditions.")
# print("7. Single carriageways experience the highest number of accidents.")
# print("8. Time of day influences accident severity, with night accidents being more severe.")
# print("9. Buses and large vehicles have a lower accident frequency but a higher severity impact.")
# print("10. Predictive modeling suggests a combination of road conditions, light, and vehicle type impacts severity levels.")
